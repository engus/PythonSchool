# %% [markdown]
# ### Modul 1. lesson 1 - 8

# %%
user_ids = []

with open('user_ids.txt', 'r') as f:
    for line in f:
        user_ids.append(line.strip())
print(len(user_ids))
# Out:
# 294

# %%
list_of_zeros_and_ones = [ 0, 1, 0, 1, 0, 1 ]

print (set(list_of_zeros_and_ones))
# Out:
# {0, 1}

# %%
print(len(set(user_ids)))
# Out:
# 124

# %%
with open('user_ids_headers.txt', 'r') as f:
    next(f)
    for line in f:
        print(line.strip())
# Out:
# 1010
# 1036
# 1041
# 1041
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1047
# 1047
# 1052
# 1052
# 1057
# 1057
# 1062
# 1067
# 1078
# 1085
# 1096
# 1098
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1105
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1111
# 1112
# 1112
# 1113
# 1113
# 1114
# 1114
# 1116
# 1118
# 1118
# 1123
# 1123
# 1128
# 1134
# 1134
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1136
# 1136
# 1140
# 1140
# 1141
# 1145
# 1145
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1150
# 1154
# 1154
# 1159
# 1159
# 1164
# 1167
# 1175
# 1181
# 1182
# 1182
# 1193
# 1193
# 1198
# 1198
# 1201
# 1203
# 1203
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1208
# 1208
# 1209
# 1213
# 1213
# 1218
# 1218
# 1219
# 1223
# 1223
# 1224
# 1226
# 1226
# 1228
# 1228
# 1230
# 1233
# 1233
# 1236
# 1238
# 1238
# 1242
# 1243
# 1243
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1248
# 1248
# 1252
# 1252
# 1253
# 1253
# 1258
# 1258
# 1263
# 1263
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1268
# 1268
# 1269
# 1270
# 1273
# 1273
# 1274
# 1278
# 1278
# 1279
# 1281
# 1283
# 1283
# 1288
# 1288
# 1291
# 1293
# 1293
# 1294
# 1296
# 1298
# 1298
# 1298
# 1300
# 1300
# 1302
# 1303
# 1303
# 1308
# 1308
# 1313
# 1313
# 1315
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1320
# 1323
# 1323
# 1328
# 1328
# 1330
# 1331
# 1332
# 1333
# 1334
# 1343
# 1350
# 1351
# 1353
# 1354
# 1355
# 1359
# 1362
# 1363
# 1364
# 1366
# 1367
# 1371
# 1372
# 1374
# 1377
# 1380
# 1382
# 1383
# 1386
# 1387
# 1388
# 1392
# 1393
# 1394
# 1397
# 1398
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424

# %%
with open('data_3_columns.txt', 'r') as f:
    for line in f:
        print(line.strip(), type(line.strip()), line.strip().split('\t'), type(line.strip().split('\t')))
# Out:
# seo	google	20,20 <class 'str'> ['seo', 'google', '20,20'] <class 'list'>
# sem	yandex	15,60 <class 'str'> ['sem', 'yandex', '15,60'] <class 'list'>
# email	promo	13,20 <class 'str'> ['email', 'promo', '13,20'] <class 'list'>
# sem	yandex	9,80 <class 'str'> ['sem', 'yandex', '9,80'] <class 'list'>
# sem	google	14,80 <class 'str'> ['sem', 'google', '14,80'] <class 'list'>
# sem	google	14,40 <class 'str'> ['sem', 'google', '14,40'] <class 'list'>
# sem	google	14,00 <class 'str'> ['sem', 'google', '14,00'] <class 'list'>
# brand	yandex	20,00 <class 'str'> ['brand', 'yandex', '20,00'] <class 'list'>
# sem	yandex	16,20 <class 'str'> ['sem', 'yandex', '16,20'] <class 'list'>
# email	promo	11,00 <class 'str'> ['email', 'promo', '11,00'] <class 'list'>
# cpa-partners	burgerclub	10,80 <class 'str'> ['cpa-partners', 'burgerclub', '10,80'] <class 'list'>
# seo	google	22,60 <class 'str'> ['seo', 'google', '22,60'] <class 'list'>
# seo	google	22,40 <class 'str'> ['seo', 'google', '22,40'] <class 'list'>
# sem	yandex	24,40 <class 'str'> ['sem', 'yandex', '24,40'] <class 'list'>
# seo	google	16,60 <class 'str'> ['seo', 'google', '16,60'] <class 'list'>
# sem	yandex	8,60 <class 'str'> ['sem', 'yandex', '8,60'] <class 'list'>
# seo	yandex	12,40 <class 'str'> ['seo', 'yandex', '12,40'] <class 'list'>
# cpa-partners	food-delivery	16,20 <class 'str'> ['cpa-partners', 'food-delivery', '16,20'] <class 'list'>
# email	promo	24,00 <class 'str'> ['email', 'promo', '24,00'] <class 'list'>
# sem	yandex	18,80 <class 'str'> ['sem', 'yandex', '18,80'] <class 'list'>
# email	promo	11,80 <class 'str'> ['email', 'promo', '11,80'] <class 'list'>
# sem	google	9,40 <class 'str'> ['sem', 'google', '9,40'] <class 'list'>
# sem	google	11,20 <class 'str'> ['sem', 'google', '11,20'] <class 'list'>
# email	promo	19,00 <class 'str'> ['email', 'promo', '19,00'] <class 'list'>
# sem	google	23,40 <class 'str'> ['sem', 'google', '23,40'] <class 'list'>
# cpc-partners	city-magazine	17,00 <class 'str'> ['cpc-partners', 'city-magazine', '17,00'] <class 'list'>
# seo	google	20,80 <class 'str'> ['seo', 'google', '20,80'] <class 'list'>
# email	promo	15,60 <class 'str'> ['email', 'promo', '15,60'] <class 'list'>
# cpc-partners	foody	22,40 <class 'str'> ['cpc-partners', 'foody', '22,40'] <class 'list'>
# seo	yandex	15,60 <class 'str'> ['seo', 'yandex', '15,60'] <class 'list'>
# cpa-partners	food-delivery	21,00 <class 'str'> ['cpa-partners', 'food-delivery', '21,00'] <class 'list'>
# seo	google	22,40 <class 'str'> ['seo', 'google', '22,40'] <class 'list'>
# sem	google	20,40 <class 'str'> ['sem', 'google', '20,40'] <class 'list'>
# email	promo	26,00 <class 'str'> ['email', 'promo', '26,00'] <class 'list'>
# seo	yandex	18,40 <class 'str'> ['seo', 'yandex', '18,40'] <class 'list'>
# email	promo	14,60 <class 'str'> ['email', 'promo', '14,60'] <class 'list'>
# seo	yandex	29,80 <class 'str'> ['seo', 'yandex', '29,80'] <class 'list'>
# email	promo	20,00 <class 'str'> ['email', 'promo', '20,00'] <class 'list'>
# sem	google	19,00 <class 'str'> ['sem', 'google', '19,00'] <class 'list'>
# brand	google	16,40 <class 'str'> ['brand', 'google', '16,40'] <class 'list'>
# sem	yandex	16,20 <class 'str'> ['sem', 'yandex', '16,20'] <class 'list'>
# sem	yandex	17,80 <class 'str'> ['sem', 'yandex', '17,80'] <class 'list'>
# email	promo	18,80 <class 'str'> ['email', 'promo', '18,80'] <class 'list'>
# cpa-partners	burgerclub	20,00 <class 'str'> ['cpa-partners', 'burgerclub', '20,00'] <class 'list'>
# seo	google	21,00 <class 'str'> ['seo', 'google', '21,00'] <class 'list'>
# seo	yandex	16,60 <class 'str'> ['seo', 'yandex', '16,60'] <class 'list'>
# email	promo	20,00 <class 'str'> ['email', 'promo', '20,00'] <class 'list'>
# sem	yandex	19,80 <class 'str'> ['sem', 'yandex', '19,80'] <class 'list'>
# email	promo	16,80 <class 'str'> ['email', 'promo', '16,80'] <class 'list'>
# cpa-partners	food-delivery	24,00 <class 'str'> ['cpa-partners', 'food-delivery', '24,00'] <class 'list'>
# sem	yandex	12,00 <class 'str'> ['sem', 'yandex', '12,00'] <class 'list'>
# sem	yandex	10,20 <class 'str'> ['sem', 'yandex', '10,20'] <class 'list'>
# email	promo	24,00 <class 'str'> ['email', 'promo', '24,00'] <class 'list'>
# sem	yandex	15,80 <class 'str'> ['sem', 'yandex', '15,80'] <class 'list'>
# sem	yandex	22,00 <class 'str'> ['sem', 'yandex', '22,00'] <class 'list'>
# sem	google	17,40 <class 'str'> ['sem', 'google', '17,40'] <class 'list'>
# sem	yandex	14,80 <class 'str'> ['sem', 'yandex', '14,80'] <class 'list'>
# email	promo	20,00 <class 'str'> ['email', 'promo', '20,00'] <class 'list'>
# brand	yandex	11,60 <class 'str'> ['brand', 'yandex', '11,60'] <class 'list'>
# seo	yandex	20,00 <class 'str'> ['seo', 'yandex', '20,00'] <class 'list'>
# sem	yandex	16,00 <class 'str'> ['sem', 'yandex', '16,00'] <class 'list'>
# seo	yandex	11,20 <class 'str'> ['seo', 'yandex', '11,20'] <class 'list'>
# seo	google	12,20 <class 'str'> ['seo', 'google', '12,20'] <class 'list'>
# sem	yandex	19,20 <class 'str'> ['sem', 'yandex', '19,20'] <class 'list'>
# sem	google	17,80 <class 'str'> ['sem', 'google', '17,80'] <class 'list'>
# sem	google	19,80 <class 'str'> ['sem', 'google', '19,80'] <class 'list'>
# email	promo	8,60 <class 'str'> ['email', 'promo', '8,60'] <class 'list'>
# email	promo	28,60 <class 'str'> ['email', 'promo', '28,60'] <class 'list'>
# email	newsletter	18,80 <class 'str'> ['email', 'newsletter', '18,80'] <class 'list'>
# sem	google	17,60 <class 'str'> ['sem', 'google', '17,60'] <class 'list'>
# email	promo	16,00 <class 'str'> ['email', 'promo', '16,00'] <class 'list'>
# cpa-partners	food-delivery	15,40 <class 'str'> ['cpa-partners', 'food-delivery', '15,40'] <class 'list'>
# sem	yandex	21,60 <class 'str'> ['sem', 'yandex', '21,60'] <class 'list'>
# email	promo	7,60 <class 'str'> ['email', 'promo', '7,60'] <class 'list'>
# brand	yandex	21,60 <class 'str'> ['brand', 'yandex', '21,60'] <class 'list'>
# smm	facebook	17,40 <class 'str'> ['smm', 'facebook', '17,40'] <class 'list'>
# sem	google	22,00 <class 'str'> ['sem', 'google', '22,00'] <class 'list'>
# email	promo	22,00 <class 'str'> ['email', 'promo', '22,00'] <class 'list'>
# email	promo	16,00 <class 'str'> ['email', 'promo', '16,00'] <class 'list'>
# seo	yandex	16,00 <class 'str'> ['seo', 'yandex', '16,00'] <class 'list'>
# sem	yandex	20,00 <class 'str'> ['sem', 'yandex', '20,00'] <class 'list'>
# email	promo	10,00 <class 'str'> ['email', 'promo', '10,00'] <class 'list'>
# sem	yandex	21,20 <class 'str'> ['sem', 'yandex', '21,20'] <class 'list'>
# seo	yandex	30,40 <class 'str'> ['seo', 'yandex', '30,40'] <class 'list'>
# cpa-partners	burgerclub	18,80 <class 'str'> ['cpa-partners', 'burgerclub', '18,80'] <class 'list'>
# sem	yandex	14,00 <class 'str'> ['sem', 'yandex', '14,00'] <class 'list'>
# email	promo	22,00 <class 'str'> ['email', 'promo', '22,00'] <class 'list'>
# sem	google	16,00 <class 'str'> ['sem', 'google', '16,00'] <class 'list'>
# sem	yandex	12,60 <class 'str'> ['sem', 'yandex', '12,60'] <class 'list'>
# sem	google	13,40 <class 'str'> ['sem', 'google', '13,40'] <class 'list'>
# seo	yandex	13,60 <class 'str'> ['seo', 'yandex', '13,60'] <class 'list'>
# sem	yandex	10,20 <class 'str'> ['sem', 'yandex', '10,20'] <class 'list'>
# brand	yandex	17,40 <class 'str'> ['brand', 'yandex', '17,40'] <class 'list'>
# sem	google	22,40 <class 'str'> ['sem', 'google', '22,40'] <class 'list'>
# sem	yandex	11,40 <class 'str'> ['sem', 'yandex', '11,40'] <class 'list'>
# sem	google	14,00 <class 'str'> ['sem', 'google', '14,00'] <class 'list'>
# seo	yandex	22,40 <class 'str'> ['seo', 'yandex', '22,40'] <class 'list'>
# sem	yandex	18,00 <class 'str'> ['sem', 'yandex', '18,00'] <class 'list'>
# brand	direct	17,00 <class 'str'> ['brand', 'direct', '17,00'] <class 'list'>
# cpa-partners	food-delivery	24,80 <class 'str'> ['cpa-partners', 'food-delivery', '24,80'] <class 'list'>
# brand	google	16,60 <class 'str'> ['brand', 'google', '16,60'] <class 'list'>
# sem	google	17,80 <class 'str'> ['sem', 'google', '17,80'] <class 'list'>
# sem	google	9,00 <class 'str'> ['sem', 'google', '9,00'] <class 'list'>
# email	promo	10,60 <class 'str'> ['email', 'promo', '10,60'] <class 'list'>
# brand	google	23,40 <class 'str'> ['brand', 'google', '23,40'] <class 'list'>
# cpa-partners	burgerclub	21,00 <class 'str'> ['cpa-partners', 'burgerclub', '21,00'] <class 'list'>
# email	promo	16,60 <class 'str'> ['email', 'promo', '16,60'] <class 'list'>
# cpc-partners	foody	24,20 <class 'str'> ['cpc-partners', 'foody', '24,20'] <class 'list'>
# seo	google	20,40 <class 'str'> ['seo', 'google', '20,40'] <class 'list'>
# seo	yandex	25,60 <class 'str'> ['seo', 'yandex', '25,60'] <class 'list'>
# brand	yandex	19,80 <class 'str'> ['brand', 'yandex', '19,80'] <class 'list'>
# smm	facebook	16,40 <class 'str'> ['smm', 'facebook', '16,40'] <class 'list'>
# email	promo	16,20 <class 'str'> ['email', 'promo', '16,20'] <class 'list'>
# seo	yandex	17,00 <class 'str'> ['seo', 'yandex', '17,00'] <class 'list'>
# email	promo	16,80 <class 'str'> ['email', 'promo', '16,80'] <class 'list'>
# sem	yandex	19,80 <class 'str'> ['sem', 'yandex', '19,80'] <class 'list'>
# seo	yandex	15,60 <class 'str'> ['seo', 'yandex', '15,60'] <class 'list'>
# email	newsletter	19,20 <class 'str'> ['email', 'newsletter', '19,20'] <class 'list'>
# sem	google	23,20 <class 'str'> ['sem', 'google', '23,20'] <class 'list'>
# sem	yandex	10,80 <class 'str'> ['sem', 'yandex', '10,80'] <class 'list'>
# sem	google	24,40 <class 'str'> ['sem', 'google', '24,40'] <class 'list'>
# sem	yandex	13,40 <class 'str'> ['sem', 'yandex', '13,40'] <class 'list'>
# seo	yandex	12,00 <class 'str'> ['seo', 'yandex', '12,00'] <class 'list'>
# smm	facebook	18,60 <class 'str'> ['smm', 'facebook', '18,60'] <class 'list'>
# sem	google	16,60 <class 'str'> ['sem', 'google', '16,60'] <class 'list'>
# cpa-partners	burgerclub	12,20 <class 'str'> ['cpa-partners', 'burgerclub', '12,20'] <class 'list'>
# cpa-partners	burgerclub	22,40 <class 'str'> ['cpa-partners', 'burgerclub', '22,40'] <class 'list'>
# seo	google	15,40 <class 'str'> ['seo', 'google', '15,40'] <class 'list'>
# cpc-partners	city-magazine	17,20 <class 'str'> ['cpc-partners', 'city-magazine', '17,20'] <class 'list'>
# cpa-partners	burgerclub	17,60 <class 'str'> ['cpa-partners', 'burgerclub', '17,60'] <class 'list'>
# email	promo	16,40 <class 'str'> ['email', 'promo', '16,40'] <class 'list'>
# email	promo	18,60 <class 'str'> ['email', 'promo', '18,60'] <class 'list'>
# email	promo	19,80 <class 'str'> ['email', 'promo', '19,80'] <class 'list'>
# brand	google	18,80 <class 'str'> ['brand', 'google', '18,80'] <class 'list'>
# seo	google	17,60 <class 'str'> ['seo', 'google', '17,60'] <class 'list'>
# email	promo	20,60 <class 'str'> ['email', 'promo', '20,60'] <class 'list'>
# cpa-partners	food-delivery	15,00 <class 'str'> ['cpa-partners', 'food-delivery', '15,00'] <class 'list'>
# sem	yandex	22,00 <class 'str'> ['sem', 'yandex', '22,00'] <class 'list'>
# email	promo	17,40 <class 'str'> ['email', 'promo', '17,40'] <class 'list'>
# seo	yandex	13,60 <class 'str'> ['seo', 'yandex', '13,60'] <class 'list'>
# seo	yandex	17,60 <class 'str'> ['seo', 'yandex', '17,60'] <class 'list'>
# email	promo	18,40 <class 'str'> ['email', 'promo', '18,40'] <class 'list'>
# email	promo	20,40 <class 'str'> ['email', 'promo', '20,40'] <class 'list'>
# sem	yandex	20,00 <class 'str'> ['sem', 'yandex', '20,00'] <class 'list'>
# brand	yandex	17,80 <class 'str'> ['brand', 'yandex', '17,80'] <class 'list'>
# seo	google	16,00 <class 'str'> ['seo', 'google', '16,00'] <class 'list'>
# email	promo	14,60 <class 'str'> ['email', 'promo', '14,60'] <class 'list'>
# email	promo	17,20 <class 'str'> ['email', 'promo', '17,20'] <class 'list'>
# sem	yandex	13,60 <class 'str'> ['sem', 'yandex', '13,60'] <class 'list'>
# email	promo	23,60 <class 'str'> ['email', 'promo', '23,60'] <class 'list'>
# sem	google	15,60 <class 'str'> ['sem', 'google', '15,60'] <class 'list'>
# sem	yandex	21,40 <class 'str'> ['sem', 'yandex', '21,40'] <class 'list'>
# sem	google	13,00 <class 'str'> ['sem', 'google', '13,00'] <class 'list'>
# seo	yandex	18,60 <class 'str'> ['seo', 'yandex', '18,60'] <class 'list'>
# cpa-partners	burgerclub	20,60 <class 'str'> ['cpa-partners', 'burgerclub', '20,60'] <class 'list'>
# seo	yandex	11,40 <class 'str'> ['seo', 'yandex', '11,40'] <class 'list'>
# email	promo	18,00 <class 'str'> ['email', 'promo', '18,00'] <class 'list'>
# smm	vk	12,00 <class 'str'> ['smm', 'vk', '12,00'] <class 'list'>
# sem	yandex	16,00 <class 'str'> ['sem', 'yandex', '16,00'] <class 'list'>
# sem	google	12,20 <class 'str'> ['sem', 'google', '12,20'] <class 'list'>
# brand	direct	23,00 <class 'str'> ['brand', 'direct', '23,00'] <class 'list'>
# sem	yandex	24,00 <class 'str'> ['sem', 'yandex', '24,00'] <class 'list'>
# email	promo	11,80 <class 'str'> ['email', 'promo', '11,80'] <class 'list'>
# email	newsletter	17,20 <class 'str'> ['email', 'newsletter', '17,20'] <class 'list'>
# email	newsletter	24,60 <class 'str'> ['email', 'newsletter', '24,60'] <class 'list'>
# sem	yandex	30,40 <class 'str'> ['sem', 'yandex', '30,40'] <class 'list'>
# sem	yandex	18,00 <class 'str'> ['sem', 'yandex', '18,00'] <class 'list'>
# email	promo	15,00 <class 'str'> ['email', 'promo', '15,00'] <class 'list'>
# sem	google	13,20 <class 'str'> ['sem', 'google', '13,20'] <class 'list'>
# seo	yandex	28,80 <class 'str'> ['seo', 'yandex', '28,80'] <class 'list'>
# sem	yandex	22,00 <class 'str'> ['sem', 'yandex', '22,00'] <class 'list'>
# email	promo	15,60 <class 'str'> ['email', 'promo', '15,60'] <class 'list'>
# sem	yandex	13,60 <class 'str'> ['sem', 'yandex', '13,60'] <class 'list'>
# sem	google	8,60 <class 'str'> ['sem', 'google', '8,60'] <class 'list'>
# sem	google	22,00 <class 'str'> ['sem', 'google', '22,00'] <class 'list'>
# email	promo	20,00 <class 'str'> ['email', 'promo', '20,00'] <class 'list'>
# sem	yandex	12,60 <class 'str'> ['sem', 'yandex', '12,60'] <class 'list'>
# sem	google	18,00 <class 'str'> ['sem', 'google', '18,00'] <class 'list'>
# brand	direct	11,00 <class 'str'> ['brand', 'direct', '11,00'] <class 'list'>
# email	promo	12,20 <class 'str'> ['email', 'promo', '12,20'] <class 'list'>
# sem	yandex	18,00 <class 'str'> ['sem', 'yandex', '18,00'] <class 'list'>
# email	promo	12,40 <class 'str'> ['email', 'promo', '12,40'] <class 'list'>
# seo	google	13,00 <class 'str'> ['seo', 'google', '13,00'] <class 'list'>
# brand	direct	21,40 <class 'str'> ['brand', 'direct', '21,40'] <class 'list'>
# sem	yandex	13,60 <class 'str'> ['sem', 'yandex', '13,60'] <class 'list'>
# cpa-partners	food-delivery	17,40 <class 'str'> ['cpa-partners', 'food-delivery', '17,40'] <class 'list'>
# sem	google	15,00 <class 'str'> ['sem', 'google', '15,00'] <class 'list'>
# seo	yandex	14,40 <class 'str'> ['seo', 'yandex', '14,40'] <class 'list'>
# brand	direct	16,00 <class 'str'> ['brand', 'direct', '16,00'] <class 'list'>
# seo	yandex	12,00 <class 'str'> ['seo', 'yandex', '12,00'] <class 'list'>
# sem	yandex	12,80 <class 'str'> ['sem', 'yandex', '12,80'] <class 'list'>
# email	promo	21,40 <class 'str'> ['email', 'promo', '21,40'] <class 'list'>
# sem	yandex	17,40 <class 'str'> ['sem', 'yandex', '17,40'] <class 'list'>
# sem	yandex	21,60 <class 'str'> ['sem', 'yandex', '21,60'] <class 'list'>
# email	promo	16,00 <class 'str'> ['email', 'promo', '16,00'] <class 'list'>
# sem	google	16,40 <class 'str'> ['sem', 'google', '16,40'] <class 'list'>
# sem	yandex	16,00 <class 'str'> ['sem', 'yandex', '16,00'] <class 'list'>
# email	promo	22,00 <class 'str'> ['email', 'promo', '22,00'] <class 'list'>
# brand	yandex	21,80 <class 'str'> ['brand', 'yandex', '21,80'] <class 'list'>
# email	promo	14,60 <class 'str'> ['email', 'promo', '14,60'] <class 'list'>
# seo	yandex	22,00 <class 'str'> ['seo', 'yandex', '22,00'] <class 'list'>
# email	promo	25,00 <class 'str'> ['email', 'promo', '25,00'] <class 'list'>
# sem	google	15,60 <class 'str'> ['sem', 'google', '15,60'] <class 'list'>
# email	promo	17,80 <class 'str'> ['email', 'promo', '17,80'] <class 'list'>
# sem	yandex	14,80 <class 'str'> ['sem', 'yandex', '14,80'] <class 'list'>
# sem	yandex	18,20 <class 'str'> ['sem', 'yandex', '18,20'] <class 'list'>
# sem	google	12,60 <class 'str'> ['sem', 'google', '12,60'] <class 'list'>
# email	promo	11,80 <class 'str'> ['email', 'promo', '11,80'] <class 'list'>
# sem	yandex	16,00 <class 'str'> ['sem', 'yandex', '16,00'] <class 'list'>
# seo	yandex	30,40 <class 'str'> ['seo', 'yandex', '30,40'] <class 'list'>
# seo	google	13,40 <class 'str'> ['seo', 'google', '13,40'] <class 'list'>
# email	newsletter	18,40 <class 'str'> ['email', 'newsletter', '18,40'] <class 'list'>
# email	promo	20,00 <class 'str'> ['email', 'promo', '20,00'] <class 'list'>
# smm	vk	17,00 <class 'str'> ['smm', 'vk', '17,00'] <class 'list'>
# sem	google	26,00 <class 'str'> ['sem', 'google', '26,00'] <class 'list'>
# sem	google	21,00 <class 'str'> ['sem', 'google', '21,00'] <class 'list'>
# cpc-partners	foody	19,40 <class 'str'> ['cpc-partners', 'foody', '19,40'] <class 'list'>
# sem	yandex	16,00 <class 'str'> ['sem', 'yandex', '16,00'] <class 'list'>
# sem	yandex	12,80 <class 'str'> ['sem', 'yandex', '12,80'] <class 'list'>
# sem	google	14,00 <class 'str'> ['sem', 'google', '14,00'] <class 'list'>
# cpa-partners	burgerclub	21,80 <class 'str'> ['cpa-partners', 'burgerclub', '21,80'] <class 'list'>
# cpc-partners	city-magazine	11,80 <class 'str'> ['cpc-partners', 'city-magazine', '11,80'] <class 'list'>
# sem	google	25,80 <class 'str'> ['sem', 'google', '25,80'] <class 'list'>
# sem	google	18,00 <class 'str'> ['sem', 'google', '18,00'] <class 'list'>
# sem	google	10,20 <class 'str'> ['sem', 'google', '10,20'] <class 'list'>
# email	promo	12,00 <class 'str'> ['email', 'promo', '12,00'] <class 'list'>
# sem	google	13,80 <class 'str'> ['sem', 'google', '13,80'] <class 'list'>
# sem	google	16,60 <class 'str'> ['sem', 'google', '16,60'] <class 'list'>
# sem	google	11,40 <class 'str'> ['sem', 'google', '11,40'] <class 'list'>
# brand	google	13,40 <class 'str'> ['brand', 'google', '13,40'] <class 'list'>
# sem	yandex	14,00 <class 'str'> ['sem', 'yandex', '14,00'] <class 'list'>
# sem	google	16,60 <class 'str'> ['sem', 'google', '16,60'] <class 'list'>
# email	promo	24,00 <class 'str'> ['email', 'promo', '24,00'] <class 'list'>
# email	promo	10,20 <class 'str'> ['email', 'promo', '10,20'] <class 'list'>
# email	promo	18,60 <class 'str'> ['email', 'promo', '18,60'] <class 'list'>
# sem	yandex	21,60 <class 'str'> ['sem', 'yandex', '21,60'] <class 'list'>
# cpa-partners	burgerclub	20,20 <class 'str'> ['cpa-partners', 'burgerclub', '20,20'] <class 'list'>
# sem	yandex	18,00 <class 'str'> ['sem', 'yandex', '18,00'] <class 'list'>
# email	promo	17,40 <class 'str'> ['email', 'promo', '17,40'] <class 'list'>
# email	promo	22,00 <class 'str'> ['email', 'promo', '22,00'] <class 'list'>
# sem	yandex	17,40 <class 'str'> ['sem', 'yandex', '17,40'] <class 'list'>
# sem	yandex	19,00 <class 'str'> ['sem', 'yandex', '19,00'] <class 'list'>
# smm	facebook	18,00 <class 'str'> ['smm', 'facebook', '18,00'] <class 'list'>
# brand	google	16,00 <class 'str'> ['brand', 'google', '16,00'] <class 'list'>
# email	promo	28,60 <class 'str'> ['email', 'promo', '28,60'] <class 'list'>
# sem	yandex	18,40 <class 'str'> ['sem', 'yandex', '18,40'] <class 'list'>
# email	promo	18,80 <class 'str'> ['email', 'promo', '18,80'] <class 'list'>
# seo	yandex	17,80 <class 'str'> ['seo', 'yandex', '17,80'] <class 'list'>
# sem	yandex	16,80 <class 'str'> ['sem', 'yandex', '16,80'] <class 'list'>
# sem	yandex	19,40 <class 'str'> ['sem', 'yandex', '19,40'] <class 'list'>
# sem	google	20,00 <class 'str'> ['sem', 'google', '20,00'] <class 'list'>
# sem	yandex	16,00 <class 'str'> ['sem', 'yandex', '16,00'] <class 'list'>
# sem	google	22,00 <class 'str'> ['sem', 'google', '22,00'] <class 'list'>
# cpa-partners	food-delivery	12,80 <class 'str'> ['cpa-partners', 'food-delivery', '12,80'] <class 'list'>
# email	promo	20,00 <class 'str'> ['email', 'promo', '20,00'] <class 'list'>
# sem	yandex	17,40 <class 'str'> ['sem', 'yandex', '17,40'] <class 'list'>
# email	promo	15,60 <class 'str'> ['email', 'promo', '15,60'] <class 'list'>
# sem	google	22,00 <class 'str'> ['sem', 'google', '22,00'] <class 'list'>
# sem	google	14,40 <class 'str'> ['sem', 'google', '14,40'] <class 'list'>
# sem	google	12,20 <class 'str'> ['sem', 'google', '12,20'] <class 'list'>
# seo	yandex	12,20 <class 'str'> ['seo', 'yandex', '12,20'] <class 'list'>
# email	promo	20,00 <class 'str'> ['email', 'promo', '20,00'] <class 'list'>
# cpa-partners	food-delivery	13,00 <class 'str'> ['cpa-partners', 'food-delivery', '13,00'] <class 'list'>
# sem	yandex	22,40 <class 'str'> ['sem', 'yandex', '22,40'] <class 'list'>
# sem	yandex	13,60 <class 'str'> ['sem', 'yandex', '13,60'] <class 'list'>
# sem	google	30,40 <class 'str'> ['sem', 'google', '30,40'] <class 'list'>
# sem	yandex	12,40 <class 'str'> ['sem', 'yandex', '12,40'] <class 'list'>
# sem	yandex	16,00 <class 'str'> ['sem', 'yandex', '16,00'] <class 'list'>
# seo	yandex	30,40 <class 'str'> ['seo', 'yandex', '30,40'] <class 'list'>
# cpc-partners	city-magazine	23,20 <class 'str'> ['cpc-partners', 'city-magazine', '23,20'] <class 'list'>
# sem	google	20,00 <class 'str'> ['sem', 'google', '20,00'] <class 'list'>
# email	promo	12,60 <class 'str'> ['email', 'promo', '12,60'] <class 'list'>
# sem	google	14,60 <class 'str'> ['sem', 'google', '14,60'] <class 'list'>
# cpc-partners	city-magazine	11,80 <class 'str'> ['cpc-partners', 'city-magazine', '11,80'] <class 'list'>
# smm	facebook	20,20 <class 'str'> ['smm', 'facebook', '20,20'] <class 'list'>
# sem	google	10,00 <class 'str'> ['sem', 'google', '10,00'] <class 'list'>
# email	promo	12,80 <class 'str'> ['email', 'promo', '12,80'] <class 'list'>
# sem	yandex	20,60 <class 'str'> ['sem', 'yandex', '20,60'] <class 'list'>
# seo	yandex	18,00 <class 'str'> ['seo', 'yandex', '18,00'] <class 'list'>
# cpa-partners	food-delivery	13,80 <class 'str'> ['cpa-partners', 'food-delivery', '13,80'] <class 'list'>
# seo	yandex	12,80 <class 'str'> ['seo', 'yandex', '12,80'] <class 'list'>
# sem	yandex	17,20 <class 'str'> ['sem', 'yandex', '17,20'] <class 'list'>
# sem	google	16,00 <class 'str'> ['sem', 'google', '16,00'] <class 'list'>
# email	promo	14,20 <class 'str'> ['email', 'promo', '14,20'] <class 'list'>
# sem	yandex	19,60 <class 'str'> ['sem', 'yandex', '19,60'] <class 'list'>
# seo	google	22,40 <class 'str'> ['seo', 'google', '22,40'] <class 'list'>
# email	promo	14,80 <class 'str'> ['email', 'promo', '14,80'] <class 'list'>
# sem	google	13,00 <class 'str'> ['sem', 'google', '13,00'] <class 'list'>
# sem	google	13,60 <class 'str'> ['sem', 'google', '13,60'] <class 'list'>
# email	promo	12,60 <class 'str'> ['email', 'promo', '12,60'] <class 'list'>
# seo	yandex	19,20 <class 'str'> ['seo', 'yandex', '19,20'] <class 'list'>
# email	promo	20,20 <class 'str'> ['email', 'promo', '20,20'] <class 'list'>
# sem	google	16,00 <class 'str'> ['sem', 'google', '16,00'] <class 'list'>
# sem	yandex	11,60 <class 'str'> ['sem', 'yandex', '11,60'] <class 'list'>

# %%
total_amount = 0
google_total_amount = 0 
yandex_seo_total_amount = 0 
with open('data_3_columns.txt', 'r') as f:
    for line in f:
        line = line.strip().split('\t')
        medium = line[0]
        source = line[1]
        amount = float(line[2].replace(',','.'))
        #print (medium, source, amount)
        if source == 'google': google_total_amount += amount
        if source == 'yandex' and medium == 'seo': yandex_seo_total_amount += amount
        total_amount+=amount
print(google_total_amount)
print(yandex_seo_total_amount)
print(total_amount)
# Out:
# 1318.8000000000002
# 555.8
# 5129.8

# %%
import openpyxl

# %%
workbook = 'data.xlsx'
sheetName = 'data'

sheet = openpyxl.load_workbook( workbook )[sheetName]

total_amount = 0
for line in sheet[ 'E2:I'+str(sheet.max_row)]:
    medium = line[0].value
    source = line[1].value
    amount_paid = line[4].value
    total_amount += amount_paid
    #print( source, medium, amount_paid)
print(total_amount)
# Out:
# 5129.8

# %%
allowed_medium = [ 'brand', 'seo' ]
allowed_source = 'yandex'

total_amount = 0

with open( 'data.txt', 'r' ) as f:
    next(f)
    for line in f:
        line = line.strip().split('\t')
        medium = line[4]
        source = line[5]            
        amount = float( line[-1].replace(',', '.') )
        #print(medium, source, amount)
        if source == allowed_source and medium in allowed_medium:
            total_amount += amount
print (total_amount)
# Out:
# 685.8000000000001

# %%
Started = True
unique_user_ids = 0

with open( 'data_no_header.txt', 'r' ) as f:
    for line in f:
        line = line.strip().split('\t')
        current_user_id = line[2]
        if Started:
            Started = False
            previous_user_id = current_user_id
            unique_user_ids += 1
        else:
            if previous_user_id != current_user_id:
                unique_user_ids += 1
        print( current_user_id, previous_user_id)
        
        previous_user_id = current_user_id
print(unique_user_ids)
# Out:
# 1010 1010
# 1036 1010
# 1041 1036
# 1041 1041
# 1042 1041
# 1042 1042
# 1042 1042
# 1042 1042
# 1042 1042
# 1042 1042
# 1042 1042
# 1042 1042
# 1042 1042
# 1042 1042
# 1042 1042
# 1042 1042
# 1047 1042
# 1047 1047
# 1052 1047
# 1052 1052
# 1057 1052
# 1057 1057
# 1062 1057
# 1067 1062
# 1078 1067
# 1085 1078
# 1096 1085
# 1098 1096
# 1100 1098
# 1100 1100
# 1100 1100
# 1100 1100
# 1100 1100
# 1100 1100
# 1100 1100
# 1100 1100
# 1100 1100
# 1100 1100
# 1100 1100
# 1100 1100
# 1105 1100
# 1108 1105
# 1108 1108
# 1108 1108
# 1108 1108
# 1108 1108
# 1108 1108
# 1108 1108
# 1108 1108
# 1108 1108
# 1111 1108
# 1112 1111
# 1112 1112
# 1113 1112
# 1113 1113
# 1114 1113
# 1114 1114
# 1116 1114
# 1118 1116
# 1118 1118
# 1123 1118
# 1123 1123
# 1128 1123
# 1134 1128
# 1134 1134
# 1135 1134
# 1135 1135
# 1135 1135
# 1135 1135
# 1135 1135
# 1135 1135
# 1135 1135
# 1135 1135
# 1135 1135
# 1136 1135
# 1136 1136
# 1140 1136
# 1140 1140
# 1141 1140
# 1145 1141
# 1145 1145
# 1149 1145
# 1149 1149
# 1149 1149
# 1149 1149
# 1149 1149
# 1149 1149
# 1149 1149
# 1150 1149
# 1154 1150
# 1154 1154
# 1159 1154
# 1159 1159
# 1164 1159
# 1167 1164
# 1175 1167
# 1181 1175
# 1182 1181
# 1182 1182
# 1193 1182
# 1193 1193
# 1198 1193
# 1198 1198
# 1201 1198
# 1203 1201
# 1203 1203
# 1207 1203
# 1207 1207
# 1207 1207
# 1207 1207
# 1207 1207
# 1207 1207
# 1207 1207
# 1207 1207
# 1207 1207
# 1207 1207
# 1207 1207
# 1207 1207
# 1207 1207
# 1207 1207
# 1208 1207
# 1208 1208
# 1209 1208
# 1213 1209
# 1213 1213
# 1218 1213
# 1218 1218
# 1219 1218
# 1223 1219
# 1223 1223
# 1224 1223
# 1226 1224
# 1226 1226
# 1228 1226
# 1228 1228
# 1230 1228
# 1233 1230
# 1233 1233
# 1236 1233
# 1238 1236
# 1238 1238
# 1242 1238
# 1243 1242
# 1243 1243
# 1246 1243
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1246 1246
# 1248 1246
# 1248 1248
# 1252 1248
# 1252 1252
# 1253 1252
# 1253 1253
# 1258 1253
# 1258 1258
# 1263 1258
# 1263 1263
# 1267 1263
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1267 1267
# 1268 1267
# 1268 1268
# 1269 1268
# 1270 1269
# 1273 1270
# 1273 1273
# 1274 1273
# 1278 1274
# 1278 1278
# 1279 1278
# 1281 1279
# 1283 1281
# 1283 1283
# 1288 1283
# 1288 1288
# 1291 1288
# 1293 1291
# 1293 1293
# 1294 1293
# 1296 1294
# 1298 1296
# 1298 1298
# 1298 1298
# 1300 1298
# 1300 1300
# 1302 1300
# 1303 1302
# 1303 1303
# 1308 1303
# 1308 1308
# 1313 1308
# 1313 1313
# 1315 1313
# 1318 1315
# 1318 1318
# 1318 1318
# 1318 1318
# 1318 1318
# 1318 1318
# 1318 1318
# 1318 1318
# 1318 1318
# 1318 1318
# 1318 1318
# 1318 1318
# 1318 1318
# 1318 1318
# 1320 1318
# 1323 1320
# 1323 1323
# 1328 1323
# 1328 1328
# 1330 1328
# 1331 1330
# 1332 1331
# 1333 1332
# 1334 1333
# 1343 1334
# 1350 1343
# 1351 1350
# 1353 1351
# 1354 1353
# 1355 1354
# 1359 1355
# 1362 1359
# 1363 1362
# 1364 1363
# 1366 1364
# 1367 1366
# 1371 1367
# 1372 1371
# 1374 1372
# 1377 1374
# 1380 1377
# 1382 1380
# 1383 1382
# 1386 1383
# 1387 1386
# 1388 1387
# 1392 1388
# 1393 1392
# 1394 1393
# 1397 1394
# 1398 1397
# 1424 1398
# 1424 1424
# 1424 1424
# 1424 1424
# 1424 1424
# 1424 1424
# 1424 1424
# 1424 1424
# 1424 1424
# 1424 1424
# 1424 1424
# 1424 1424
# 1424 1424
# 1424 1424
# 1424 1424
# 124

# %%
total_costs = { 'google': 1319, 'yandex': 1818, 'promo': 1181 }

print(total_costs['google'] + total_costs['promo'])
# Out:
# 2500

# %%
source = 'google'
if source in total_costs:
    print('here')
else: print('not here')
# Out:
# here

# %%
for key in total_costs.keys():
    print( key )
# Out:
# google
# yandex
# promo

# %%
for value in total_costs.values():
    print( value )
# Out:
# 1319
# 1818
# 1181

# %%
for key, value in total_costs.items():
    print( key, value, type(value) )
# Out:
# google 1319 <class 'int'>
# yandex 1818 <class 'int'>
# promo 1181 <class 'int'>

# %%
campaign_stats = {
    'google': { 'cost': 1000, 'clicks': 500 },
    'yandex': { 'cost': 1500, 'clicks': 900 }
}

for campaign, stats in campaign_stats.items():
    print( 'Кампания {}, цена клика {:.2f} USD'.format( campaign, stats['cost'] / stats['clicks'] ) )
# Out:
# Кампания google, цена клика 2.00 USD
# Кампания yandex, цена клика 1.67 USD

# %%
users_stats_dict = {}
i = 0
with open('data_no_header.txt', 'r') as f:
    for line in f:
        line = line.strip().split('\t')
        current_user_id = line[2]
        
        if current_user_id in users_stats_dict:
            users_stats_dict[current_user_id] += 1
        else:
            users_stats_dict[current_user_id] = 1


            print(users_stats_dict['1042'])
# Out:
# 12

# %%
""" Функция классифицирует источник трафика в зависимости от значения source и medium.
    Возвращает название типа источника по правилам:
        - если source равен 'google' или 'yandex', то проверяем medium:
            - для medium 'seo' или 'sem' возвращаем 'search engines seo'
            - для medium 'brand' - возвращаем 'search engines brand'
            - для остальных случаев возвращаем 'search engines undefined'
        - если условие не выполнено, то возвращаем 'other' """
def source_type_classification(source, medium):
    if source == 'google' or source == 'yandex':
        if medium == 'seo' or medium == 'sem':
            sourceType = 'search engines seo'
        elif medium == 'brand':
            sourceType = 'search engines brand'
        else:
            sourceType = 'search engines undefined'
    else:
        sourceType = 'other'
    return(sourceType)

source_type_stats = {}

with open( 'data_no_header.txt', 'r' ) as f:
    for line in f:
        line = line.strip().split('\t')
        source = line[5]
        medium = line[4]
        
        sourceType = source_type_classification( source, medium )
        print(source_type_classification(source, medium))
        if sourceType in source_type_stats:
            source_type_stats[ sourceType ] += 1
        else:
            source_type_stats[ sourceType ] = 1
print (source_type_stats)
# Out:
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines brand
# search engines seo
# other
# other
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# other
# other
# search engines seo
# other
# search engines seo
# search engines seo
# other
# search engines seo
# other
# search engines seo
# other
# other
# search engines seo
# other
# search engines seo
# search engines seo
# other
# search engines seo
# other
# search engines seo
# other
# search engines seo
# search engines brand
# search engines seo
# search engines seo
# other
# other
# search engines seo
# search engines seo
# other
# search engines seo
# other
# other
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# other
# search engines brand
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# other
# other
# other
# search engines seo
# other
# other
# search engines seo
# other
# search engines brand
# other
# search engines seo
# other
# other
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# other
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines brand
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# other
# other
# search engines brand
# search engines seo
# search engines seo
# other
# search engines brand
# other
# other
# other
# search engines seo
# search engines seo
# search engines brand
# other
# other
# search engines seo
# other
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# other
# search engines seo
# other
# other
# search engines seo
# other
# other
# other
# other
# other
# search engines brand
# search engines seo
# other
# other
# search engines seo
# other
# search engines seo
# search engines seo
# other
# other
# search engines seo
# search engines brand
# search engines seo
# other
# other
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# other
# search engines seo
# other
# other
# search engines seo
# search engines seo
# other
# search engines seo
# other
# other
# other
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# other
# other
# search engines seo
# other
# search engines seo
# other
# search engines seo
# other
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# other
# search engines brand
# other
# search engines seo
# other
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# other
# other
# other
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# other
# other
# search engines seo
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# search engines brand
# search engines seo
# search engines seo
# other
# other
# other
# search engines seo
# other
# search engines seo
# other
# other
# search engines seo
# search engines seo
# other
# search engines brand
# other
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# other
# other
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# other
# other
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# search engines seo
# other
# search engines seo
# other
# search engines seo
# other
# other
# search engines seo
# other
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# other
# search engines seo
# search engines seo
# other
# search engines seo
# other
# search engines seo
# search engines seo
# {'search engines seo': 168, 'other': 113, 'search engines brand': 13}

# %%
""" Функция классифицирует источник трафика в зависимости от значения source и medium.

    Пример строки на входе функции:
    ['40443', '05.10.2016 23:18', '1010', '0,000925926', 'seo', 'google', '0', '6243', '20,20']
    
    Возвращает название типа источника по правилам:
        - если source равен 'google' или 'yandex', то проверяем medium:
            - для medium 'seo' или 'sem' возвращаем 'search engines seo'
            - для medium 'brand' - возвращаем 'search engines brand'
            - для остальных случаев возвращаем 'search engines undefined'
        - если условие не выполнено, то возвращаем 'other' """
def source_type_classification(line):
    source = line[5]
    medium = line[4]
    amount_paid = float( line[-1].replace(',', '.') )
    if source == 'google' or source == 'yandex':
        if medium == 'seo' or medium == 'sem':
            sourceType = 'search engines seo'
        elif medium == 'brand':
            sourceType = 'search engines brand'
        else:
            sourceType = 'search engines undefined'
    else:
        sourceType = 'other'
        
    if amount_paid >= 20:
        orderType = 'expensive' 
    else:
        orderType = 'cheap'     
    return sourceType, orderType


source_type_stats = {}

with open( 'data_no_header.txt', 'r' ) as f:
    for line in f:
        line = line.strip().split('\t')
        
        sourceType, orderType = source_type_classification( line )
        source_order_type = sourceType + ' ' + orderType
        if source_order_type in source_type_stats:
            source_type_stats[ source_order_type ] += 1
        else:
            source_type_stats[ source_order_type ] = 1

print (source_type_stats)
# Out:
# {'search engines seo expensive': 47, 'search engines seo cheap': 121, 'other cheap': 74, 'search engines brand expensive': 4, 'other expensive': 39, 'search engines brand cheap': 9}

# %%
cpa_commission = {
    'burgerclub': 0.3,
    'food-delivery': 0.25
}

cpc_commission = {
    'city-magazine': 7,
    'foody': 9
}

fixed_commission = 4


""" 
Функция по названию канала source возвращает размер комиссии.
Размеры комиссий берутся из словарей cpa_commission, cpc_commission и значения fixed_commission
"""
def costs_classification( amount_paid, source ):
    commission = fixed_commission
    
    if source in cpa_commission:
        commission = amount_paid * cpa_commission[source]

    if source in cpc_commission:
        commission = cpc_commission[source]
    return commission



"""
Функция для строки line возвращает итоговый расход и доход
"""
def expense_and_income( line ):
    source = line[5]
    amount_paid = float( line[-1].replace( ',', '.' ) )
    cost = float( line[6].replace( ',', '.' ) )
    partner_comission = costs_classification( amount_paid, source )    
    return source, cost + partner_comission, amount_paid

roi_stats = {}
with open( 'data_no_header.txt', 'r' ) as f:
    for line in f:
        line = line.strip().split('\t')
        source, cost, income = expense_and_income( line )
        if source in roi_stats:
            roi_stats[ source ][ 'cost' ] += cost
            roi_stats[ source ][ 'income' ] += income
        else:
            roi_stats[ source ] = {}
            roi_stats[ source ][ 'cost' ] = cost
            roi_stats[ source ][ 'income' ] = income

for source, data in roi_stats.items():
    data['roi'] = ( data['income'] - data['cost'] ) / data['cost']

for source, data in roi_stats.items():
    print( '{}\t{:.2f}'.format( source, data['roi'] ) )
# Out:
# google	3.19
# yandex	3.29
# promo	3.34
# burgerclub	1.64
# food-delivery	1.56
# city-magazine	1.26
# foody	1.42
# newsletter	3.91
# facebook	3.53
# direct	3.42
# vk	2.62
